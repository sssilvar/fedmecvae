# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Example usage
from mecvae.mnist import MNISTBatchEffectDataModule, visualize_samples_and_histograms


data_dir = '~/data'
mnist_dm = MNISTBatchEffectDataModule(data_dir)
mnist_dm.prepare_data()
mnist_dm.setup()

visualize_samples_and_histograms(mnist_dm, digit=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 10
#       7 mnist_dm.prepare_data()
#       8 mnist_dm.setup()
# ---> 10 visualize_samples_and_histograms(mnist_dm, digit=1)
#
# File ~/PycharmProjects/Fed-MECVAE/mecvae/mnist.py:132, in visualize_samples_and_histograms(data_module, digit, n_rows, n_cols)
#     129 sample_index = np.random.choice(digit_indices[batch_indices])
#     131 # Get the sample image and plot it
# --> 132 img, _ = data_module.train_dataset[sample_index]
#     133 img = img.squeeze().numpy()
#     134 print(img.min(), img.max())
#
# File ~/Library/Caches/pypoetry/virtualenvs/mecvae-_b3Dgs6W-py3.11/lib/python3.11/site-packages/torchvision/datasets/mnist.py:138, in MNIST.__getitem__(self, index)
#     130 def __getitem__(self, index: int) -> Tuple[Any, Any]:
#     131     """
#     132     Args:
#     133         index (int): Index
# ...
